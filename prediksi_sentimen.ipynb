# %%
from google_play_scraper import Sort, reviews

import pandas as pd
import numpy as np

# Data Cleaning (Regular Expression)
import re
import string

# Data Preprocessing (tokenizing, stopword, stemming)
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
from nltk.corpus import stopwords
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#Scrape desired number of reviews

result, continuation_token = reviews(
    'com.strava',
    lang='id',
    country='id',
    sort=Sort.NEWEST,
    count=1000,
    filter_score_with=None,
)

# %%
df_busu = pd.DataFrame(np.array(result),columns=['review'])

df_busu = df_busu.join(pd.DataFrame(df_busu.pop('review').tolist()))

df_busu.drop_duplicates(subset = ["content"])

df_busu.head()
# Out:
#                                reviewId                   userName  \
# 0  cd552b24-0b75-4d8f-8c39-37092496ad8a     Zulliyan Aska Fadillah
# 1  afa6de00-daac-4bd3-9aad-4f75577b8816             muhizan tamimi
# 2  7e899a72-b71b-44b1-898a-b1faafb95bfb  Raditya soginanda Pratama
# 3  39f6d2c1-57c5-43a1-9658-b0b9d9c57103                    Beny AS
# 4  989fdb79-a364-4bb0-acc9-25f47194cda8          Arianto Kurniawan
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ALV-U...
# 1  https://play-lh.googleusercontent.com/a-/ALV-U...
# 2  https://play-lh.googleusercontent.com/a/ACg8oc...
# 3  https://play-lh.googleusercontent.com/a/ACg8oc...
# 4  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                              content  score  thumbsUpCount  \
# 0  Kadang aplikasinya error Mulu, terus rada kege...      3              0
# 1  Bagusnya sih karena bisa terhubung banyak akun...      5              0
# 2  strava ngebug jirlah,gw pengen log in ndak bis...      1              0
# 3                                           Good app      5              0
# 4  Sudah 2x uninstall karena error terus dari map...      4              0
#
#   reviewCreatedVersion                  at replyContent repliedAt appVersion
# 0                 None 2024-11-26 11:31:18         None      None       None
# 1               385.14 2024-11-26 04:26:10         None      None     385.14
# 2               386.13 2024-11-25 13:48:02         None      None     386.13
# 3               385.14 2024-11-25 08:35:36         None      None     385.14
# 4                 None 2024-11-24 16:10:25         None      None       None

# %%
df_busu = df_busu[['userName', 'score', 'content', 'at']]
df_busu.head()
# Out:
#                     userName  score  \
# 0     Zulliyan Aska Fadillah      3
# 1             muhizan tamimi      5
# 2  Raditya soginanda Pratama      1
# 3                    Beny AS      5
# 4          Arianto Kurniawan      4
#
#                                              content                  at
# 0  Kadang aplikasinya error Mulu, terus rada kege... 2024-11-26 11:31:18
# 1  Bagusnya sih karena bisa terhubung banyak akun... 2024-11-26 04:26:10
# 2  strava ngebug jirlah,gw pengen log in ndak bis... 2024-11-25 13:48:02
# 3                                           Good app 2024-11-25 08:35:36
# 4  Sudah 2x uninstall karena error terus dari map... 2024-11-24 16:10:25

# %%
df_busu.to_excel("strava_review.xlsx", index = False)

# %%
data = pd.read_excel("strava_review.xlsx")

data = data[(data['content'] != '') & (data['content'].notnull())]

# %%
# Define a function to clean the text
def clean_text(text):
    # Convert to lowercase
    text = text.lower()
    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))
    # Remove numbers
    text = re.sub(r'\d+', '', text)
    # Remove not alphabet 
    text = re.sub('[^a-zA-Z]', ' ', text)
    # Remove extra whitespace
    text = re.sub(r'\s+', ' ', text).strip()
    # Remove emoji (Unicode characters in a specific range)
    text = re.sub(r'[^\w\s,]', '', text, flags=re.UNICODE)
    return text

data['clean_data'] = data['content']

data['clean_data'] = data['clean_data'].apply(clean_text)
data.head(10)
# Out:
#                     userName  score  \
# 0     Zulliyan Aska Fadillah      3
# 1             muhizan tamimi      5
# 2  Raditya soginanda Pratama      1
# 3                    Beny AS      5
# 4          Arianto Kurniawan      4
# 5     Reydnal Mangerongkonda      5
# 6             novan badiyana      2
# 7                  mirib uci      5
# 8    Muh. Ramadhan Sumadaeng      5
# 9               Dedy Susanto      5
#
#                                              content                  at  \
# 0  Kadang aplikasinya error Mulu, terus rada kege... 2024-11-26 11:31:18
# 1  Bagusnya sih karena bisa terhubung banyak akun... 2024-11-26 04:26:10
# 2  strava ngebug jirlah,gw pengen log in ndak bis... 2024-11-25 13:48:02
# 3                                           Good app 2024-11-25 08:35:36
# 4  Sudah 2x uninstall karena error terus dari map... 2024-11-24 16:10:25
# 5                                          Brilliant 2024-11-24 15:10:59
# 6  terkadang larinyanya suka tidak ke detek di ra... 2024-11-24 10:15:26
# 7                 Banyak konektivitasnya jadi senang 2024-11-24 08:42:17
# 8  suka banget, jadi bisa tau seberapa jarak yg s... 2024-11-23 22:43:29
# 9                                                 Ok 2024-11-23 21:05:44
#
#                                           clean_data
# 0  kadang aplikasinya error mulu terus rada keget...
# 1  bagusnya sih karena bisa terhubung banyak akun...
# 2  strava ngebug jirlahgw pengen log in ndak bisa...
# 3                                           good app
# 4  sudah x uninstall karena error terus dari mapn...
# 5                                          brilliant
# 6  terkadang larinyanya suka tidak ke detek di ra...
# 7                 banyak konektivitasnya jadi senang
# 8  suka banget jadi bisa tau seberapa jarak yg sd...
# 9                                                 ok

# %%
data['tokenized_data'] = data['clean_data']

data['tokenized_data'] = data['tokenized_data'].apply(lambda x: word_tokenize(x))
data.head(10)
# Out:
#                     userName  score  \
# 0     Zulliyan Aska Fadillah      3
# 1             muhizan tamimi      5
# 2  Raditya soginanda Pratama      1
# 3                    Beny AS      5
# 4          Arianto Kurniawan      4
# 5     Reydnal Mangerongkonda      5
# 6             novan badiyana      2
# 7                  mirib uci      5
# 8    Muh. Ramadhan Sumadaeng      5
# 9               Dedy Susanto      5
#
#                                              content                  at  \
# 0  Kadang aplikasinya error Mulu, terus rada kege... 2024-11-26 11:31:18
# 1  Bagusnya sih karena bisa terhubung banyak akun... 2024-11-26 04:26:10
# 2  strava ngebug jirlah,gw pengen log in ndak bis... 2024-11-25 13:48:02
# 3                                           Good app 2024-11-25 08:35:36
# 4  Sudah 2x uninstall karena error terus dari map... 2024-11-24 16:10:25
# 5                                          Brilliant 2024-11-24 15:10:59
# 6  terkadang larinyanya suka tidak ke detek di ra... 2024-11-24 10:15:26
# 7                 Banyak konektivitasnya jadi senang 2024-11-24 08:42:17
# 8  suka banget, jadi bisa tau seberapa jarak yg s... 2024-11-23 22:43:29
# 9                                                 Ok 2024-11-23 21:05:44
#
#                                           clean_data  \
# 0  kadang aplikasinya error mulu terus rada keget...
# 1  bagusnya sih karena bisa terhubung banyak akun...
# 2  strava ngebug jirlahgw pengen log in ndak bisa...
# 3                                           good app
# 4  sudah x uninstall karena error terus dari mapn...
# 5                                          brilliant
# 6  terkadang larinyanya suka tidak ke detek di ra...
# 7                 banyak konektivitasnya jadi senang
# 8  suka banget jadi bisa tau seberapa jarak yg sd...
# 9                                                 ok
#
#                                       tokenized_data
# 0  [kadang, aplikasinya, error, mulu, terus, rada...
# 1  [bagusnya, sih, karena, bisa, terhubung, banya...
# 2  [strava, ngebug, jirlahgw, pengen, log, in, nd...
# 3                                        [good, app]
# 4  [sudah, x, uninstall, karena, error, terus, da...
# 5                                        [brilliant]
# 6  [terkadang, larinyanya, suka, tidak, ke, detek...
# 7            [banyak, konektivitasnya, jadi, senang]
# 8  [suka, banget, jadi, bisa, tau, seberapa, jara...
# 9                                               [ok]

# %%
# Membaca kamus normalisasi dari file teks
def load_slang_dictionary(file_path):
    slang_dict = {}
    with open(file_path, 'r', encoding='utf-8') as file:
        for line in file:
            slang, baku = line.strip().split(':', 1)
            slang_dict[slang] = baku
    return slang_dict

# Memuat kamus slang
file_path = "slangword.txt"
kata_normalisasi_dict = load_slang_dictionary(file_path)

# Fungsi untuk normalisasi kata
def normalisasi_kata(document):
    return [kata_normalisasi_dict[term] if term in kata_normalisasi_dict else term for term in document]

data['normalized_data'] = data['tokenized_data'].apply(normalisasi_kata)

data.head(10)
# Out:
#                     userName  score  \
# 0     Zulliyan Aska Fadillah      3
# 1             muhizan tamimi      5
# 2  Raditya soginanda Pratama      1
# 3                    Beny AS      5
# 4          Arianto Kurniawan      4
# 5     Reydnal Mangerongkonda      5
# 6             novan badiyana      2
# 7                  mirib uci      5
# 8    Muh. Ramadhan Sumadaeng      5
# 9               Dedy Susanto      5
#
#                                              content                  at  \
# 0  Kadang aplikasinya error Mulu, terus rada kege... 2024-11-26 11:31:18
# 1  Bagusnya sih karena bisa terhubung banyak akun... 2024-11-26 04:26:10
# 2  strava ngebug jirlah,gw pengen log in ndak bis... 2024-11-25 13:48:02
# 3                                           Good app 2024-11-25 08:35:36
# 4  Sudah 2x uninstall karena error terus dari map... 2024-11-24 16:10:25
# 5                                          Brilliant 2024-11-24 15:10:59
# 6  terkadang larinyanya suka tidak ke detek di ra... 2024-11-24 10:15:26
# 7                 Banyak konektivitasnya jadi senang 2024-11-24 08:42:17
# 8  suka banget, jadi bisa tau seberapa jarak yg s... 2024-11-23 22:43:29
# 9                                                 Ok 2024-11-23 21:05:44
#
#                                           clean_data  \
# 0  kadang aplikasinya error mulu terus rada keget...
# 1  bagusnya sih karena bisa terhubung banyak akun...
# 2  strava ngebug jirlahgw pengen log in ndak bisa...
# 3                                           good app
# 4  sudah x uninstall karena error terus dari mapn...
# 5                                          brilliant
# 6  terkadang larinyanya suka tidak ke detek di ra...
# 7                 banyak konektivitasnya jadi senang
# 8  suka banget jadi bisa tau seberapa jarak yg sd...
# 9                                                 ok
#
#                                       tokenized_data  \
# 0  [kadang, aplikasinya, error, mulu, terus, rada...
# 1  [bagusnya, sih, karena, bisa, terhubung, banya...
# 2  [strava, ngebug, jirlahgw, pengen, log, in, nd...
# 3                                        [good, app]
# 4  [sudah, x, uninstall, karena, error, terus, da...
# 5                                        [brilliant]
# 6  [terkadang, larinyanya, suka, tidak, ke, detek...
# 7            [banyak, konektivitasnya, jadi, senang]
# 8  [suka, banget, jadi, bisa, tau, seberapa, jara...
# 9                                               [ok]
#
#                                      normalized_data
# 0  [kadang, aplikasinya, error, mulu, terus, rada...
# 1  [bagusnya, sih, karena, bisa, terhubung, banya...
# 2  [strava, ngebug, jirlahgw, pengen, log, in, nd...
# 3                                   [good, aplikasi]
# 4  [sudah, kali, uninstall, karena, error, terus,...
# 5                                        [brilliant]
# 6  [terkadang, larinyanya, suka, tidak, ke, detek...
# 7            [banyak, konektivitasnya, jadi, senang]
# 8  [suka, banget, jadi, bisa, tau, seberapa, jara...
# 9                                               [ok]

# %%
# Daftar stopwords Bahasa Indonesia
stop = set(stopwords.words('indonesian'))
stop = stop.union({"nya"})

# Fungsi untuk menghapus stopwords dari list token
def remove_stopwords(tokens):
    return [word for word in tokens if word not in stop]

data['stopword_removal'] = data['normalized_data'].apply(remove_stopwords)

data.head(10)
# Out:
#                     userName  score  \
# 0     Zulliyan Aska Fadillah      3
# 1             muhizan tamimi      5
# 2  Raditya soginanda Pratama      1
# 3                    Beny AS      5
# 4          Arianto Kurniawan      4
# 5     Reydnal Mangerongkonda      5
# 6             novan badiyana      2
# 7                  mirib uci      5
# 8    Muh. Ramadhan Sumadaeng      5
# 9               Dedy Susanto      5
#
#                                              content                  at  \
# 0  Kadang aplikasinya error Mulu, terus rada kege... 2024-11-26 11:31:18
# 1  Bagusnya sih karena bisa terhubung banyak akun... 2024-11-26 04:26:10
# 2  strava ngebug jirlah,gw pengen log in ndak bis... 2024-11-25 13:48:02
# 3                                           Good app 2024-11-25 08:35:36
# 4  Sudah 2x uninstall karena error terus dari map... 2024-11-24 16:10:25
# 5                                          Brilliant 2024-11-24 15:10:59
# 6  terkadang larinyanya suka tidak ke detek di ra... 2024-11-24 10:15:26
# 7                 Banyak konektivitasnya jadi senang 2024-11-24 08:42:17
# 8  suka banget, jadi bisa tau seberapa jarak yg s... 2024-11-23 22:43:29
# 9                                                 Ok 2024-11-23 21:05:44
#
#                                           clean_data  \
# 0  kadang aplikasinya error mulu terus rada keget...
# 1  bagusnya sih karena bisa terhubung banyak akun...
# 2  strava ngebug jirlahgw pengen log in ndak bisa...
# 3                                           good app
# 4  sudah x uninstall karena error terus dari mapn...
# 5                                          brilliant
# 6  terkadang larinyanya suka tidak ke detek di ra...
# 7                 banyak konektivitasnya jadi senang
# 8  suka banget jadi bisa tau seberapa jarak yg sd...
# 9                                                 ok
#
#                                       tokenized_data  \
# 0  [kadang, aplikasinya, error, mulu, terus, rada...
# 1  [bagusnya, sih, karena, bisa, terhubung, banya...
# 2  [strava, ngebug, jirlahgw, pengen, log, in, nd...
# 3                                        [good, app]
# 4  [sudah, x, uninstall, karena, error, terus, da...
# 5                                        [brilliant]
# 6  [terkadang, larinyanya, suka, tidak, ke, detek...
# 7            [banyak, konektivitasnya, jadi, senang]
# 8  [suka, banget, jadi, bisa, tau, seberapa, jara...
# 9                                               [ok]
#
#                                      normalized_data  \
# 0  [kadang, aplikasinya, error, mulu, terus, rada...
# 1  [bagusnya, sih, karena, bisa, terhubung, banya...
# 2  [strava, ngebug, jirlahgw, pengen, log, in, nd...
# 3                                   [good, aplikasi]
# 4  [sudah, kali, uninstall, karena, error, terus,...
# 5                                        [brilliant]
# 6  [terkadang, larinyanya, suka, tidak, ke, detek...
# 7            [banyak, konektivitasnya, jadi, senang]
# 8  [suka, banget, jadi, bisa, tau, seberapa, jara...
# 9                                               [ok]
#
#                                     stopword_removal
# 0  [kadang, aplikasinya, error, mulu, rada, keget...
# 1  [bagusnya, sih, terhubung, akun, garmin, maksi...
# 2  [strava, ngebug, jirlahgw, pengen, log, in, nd...
# 3                                   [good, aplikasi]
# 4  [kali, uninstall, error, mapnya, deteksi, simp...
# 5                                        [brilliant]
# 6      [terkadang, larinyanya, suka, detek, ranking]
# 7                          [konektivitasnya, senang]
# 8               [suka, banget, tau, jarak, ditempuh]
# 9                                               [ok]

# %%
# Fungsi stemming untuk list token
def stemming_tokens(tokens):
    factory_stemmer = StemmerFactory()
    stemmer = factory_stemmer.create_stemmer()
    return [stemmer.stem(token) for token in tokens]

data['stemmed_data'] = data['stopword_removal'].apply(stemming_tokens)

data.head(10)
# Out:
#                     userName  score  \
# 0     Zulliyan Aska Fadillah      3
# 1             muhizan tamimi      5
# 2  Raditya soginanda Pratama      1
# 3                    Beny AS      5
# 4          Arianto Kurniawan      4
# 5     Reydnal Mangerongkonda      5
# 6             novan badiyana      2
# 7                  mirib uci      5
# 8    Muh. Ramadhan Sumadaeng      5
# 9               Dedy Susanto      5
#
#                                              content                  at  \
# 0  Kadang aplikasinya error Mulu, terus rada kege... 2024-11-26 11:31:18
# 1  Bagusnya sih karena bisa terhubung banyak akun... 2024-11-26 04:26:10
# 2  strava ngebug jirlah,gw pengen log in ndak bis... 2024-11-25 13:48:02
# 3                                           Good app 2024-11-25 08:35:36
# 4  Sudah 2x uninstall karena error terus dari map... 2024-11-24 16:10:25
# 5                                          Brilliant 2024-11-24 15:10:59
# 6  terkadang larinyanya suka tidak ke detek di ra... 2024-11-24 10:15:26
# 7                 Banyak konektivitasnya jadi senang 2024-11-24 08:42:17
# 8  suka banget, jadi bisa tau seberapa jarak yg s... 2024-11-23 22:43:29
# 9                                                 Ok 2024-11-23 21:05:44
#
#                                           clean_data  \
# 0  kadang aplikasinya error mulu terus rada keget...
# 1  bagusnya sih karena bisa terhubung banyak akun...
# 2  strava ngebug jirlahgw pengen log in ndak bisa...
# 3                                           good app
# 4  sudah x uninstall karena error terus dari mapn...
# 5                                          brilliant
# 6  terkadang larinyanya suka tidak ke detek di ra...
# 7                 banyak konektivitasnya jadi senang
# 8  suka banget jadi bisa tau seberapa jarak yg sd...
# 9                                                 ok
#
#                                       tokenized_data  \
# 0  [kadang, aplikasinya, error, mulu, terus, rada...
# 1  [bagusnya, sih, karena, bisa, terhubung, banya...
# 2  [strava, ngebug, jirlahgw, pengen, log, in, nd...
# 3                                        [good, app]
# 4  [sudah, x, uninstall, karena, error, terus, da...
# 5                                        [brilliant]
# 6  [terkadang, larinyanya, suka, tidak, ke, detek...
# 7            [banyak, konektivitasnya, jadi, senang]
# 8  [suka, banget, jadi, bisa, tau, seberapa, jara...
# 9                                               [ok]
#
#                                      normalized_data  \
# 0  [kadang, aplikasinya, error, mulu, terus, rada...
# 1  [bagusnya, sih, karena, bisa, terhubung, banya...
# 2  [strava, ngebug, jirlahgw, pengen, log, in, nd...
# 3                                   [good, aplikasi]
# 4  [sudah, kali, uninstall, karena, error, terus,...
# 5                                        [brilliant]
# 6  [terkadang, larinyanya, suka, tidak, ke, detek...
# 7            [banyak, konektivitasnya, jadi, senang]
# 8  [suka, banget, jadi, bisa, tau, seberapa, jara...
# 9                                               [ok]
#
#                                     stopword_removal  \
# 0  [kadang, aplikasinya, error, mulu, rada, keget...
# 1  [bagusnya, sih, terhubung, akun, garmin, maksi...
# 2  [strava, ngebug, jirlahgw, pengen, log, in, nd...
# 3                                   [good, aplikasi]
# 4  [kali, uninstall, error, mapnya, deteksi, simp...
# 5                                        [brilliant]
# 6      [terkadang, larinyanya, suka, detek, ranking]
# 7                          [konektivitasnya, senang]
# 8               [suka, banget, tau, jarak, ditempuh]
# 9                                               [ok]
#
#                                         stemmed_data
# 0  [kadang, aplikasi, error, mulu, rada, keget, s...
# 1  [bagus, sih, hubung, akun, garmin, maksimal, pro]
# 2  [strava, ngebug, jirlahgw, ken, log, in, ndak,...
# 3                                   [good, aplikasi]
# 4  [kali, uninstall, error, map, deteksi, simpan,...
# 5                                        [brilliant]
# 6      [terkadang, larinyanya, suka, detek, ranking]
# 7                          [konektivitasnya, senang]
# 8                 [suka, banget, tau, jarak, tempuh]
# 9                                               [ok]

# %%
data.to_excel("data_clean_strava.xlsx", index = False)
