# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# !kaggle datasets list -s "goal leagues"
# Out:
# ref                                                                  title                                               size  lastUpdated          downloadCount  voteCount  usabilityRating
# -------------------------------------------------------------------  -------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# slehkyi/extended-football-stats-for-european-leagues-xg              Football Data: Expected Goals and Other Metrics      1MB  2020-08-02 17:28:39           7363        160  1.0
# shreyanshkhandelwal/goal-dataset-top-5-european-leagues              Goal Dataset - Top 5 European Leagues              174KB  2021-05-23 21:20:09           6443         40  0.5294118
# khanghunhnguyntrng/football-players-transfer-fee-prediction-dataset  Football Players' Transfer Fee Prediction Dataset  549KB  2023-11-30 07:16:24           2070         42  1.0
# ...

# %%
# !kaggle datasets download shreyanshkhandelwal/goal-dataset-top-5-european-leagues
# Out:
# Dataset URL: https://www.kaggle.com/datasets/shreyanshkhandelwal/goal-dataset-top-5-european-leagues
# License(s): GPL-2.0
# ...
#   0%|          | 0.00/174k [00:00<?, ?B/s]
# 100%|██████████| 174k/174k [00:00<00:00, 279kB/s]
# 100%|██████████| 174k/174k [00:00<00:00, 278kB/s]

# %%
data_path = 'goal-dataset-top-5-european-leagues/Bundesliga-goalScorer(20-21).csv'
df = pd.read_csv(data_path)

df.head(10)
# Out:
#    Unnamed: 0    id         player_name  games  time  goals         xG  \
# 0           0   227  Robert Lewandowski     29  2467     41  32.077352
# 1           1  6170         André Silva     32  2787     28  25.599148
# 2           2  8260      Erling Haaland     28  2416     27  23.570544
# 3           3   956     Andrej Kramaric     28  2386     20  15.525608
# 4           4  7052       Wout Weghorst     34  2954     20  18.310390
# 5           5  8812      Sasa Kalajdzic     33  2146     16  11.238245
# 6           6   208         Lars Stindl     30  1985     14   9.211134
# 7           7   155           Max Kruse     22  1648     11   7.449714
# 8           8   224       Thomas Müller     32  2693     11   7.856027
# 9           9  6338        Lucas Alario     25  1238     11   7.285349
#
#    assists         xA  shots  key_passes  yellow_cards  red_cards position  \
# 0        7   4.815550    135          32             4          0      F S
# ...

# %%
data_path = 'goal-dataset-top-5-european-leagues/LaLiga-goalScorer(20-21).csv'
df = pd.read_csv(data_path)

df.head(10)
# Out:
#    Unnamed: 0    id        player_name  games  time  goals         xG  \
# 0           0  2097       Lionel Messi     35  3017     30  26.676843
# 1           1  2120      Gerard Moreno     33  2680     23  19.528129
# 2           2  2370      Karim Benzema     34  2914     23  19.454522
# 3           3  2098        Luis Suárez     32  2541     21  17.892466
# 4           4  5169  Youssef En-Nesyri     37  2218     18  15.631074
# 5           5  5232     Alexander Isak     34  2389     16  16.467688
# 6           6  2186            Morales     38  2469     14   7.804595
# 7           7  2290         Iago Aspas     33  2878     14  12.255060
# 8           8  2270  Antoine Griezmann     36  2646     13  12.428818
# 9           9  2589           Rafa Mir     38  2881     13  15.110103
#
#    assists         xA  shots  key_passes  yellow_cards  red_cards position  \
# 0        9  11.422848    195          77             4          0    F M S
# ...

# %%
data_path = 'bank/bank.csv'
df = pd.read_csv(data_path, sep=';')

df.head(10)
# Out:
#    age            job  marital  education default  balance housing loan  \
# 0   30     unemployed  married    primary      no     1787      no   no
# 1   33       services  married  secondary      no     4789     yes  yes
# 2   35     management   single   tertiary      no     1350     yes   no
# 3   30     management  married   tertiary      no     1476     yes  yes
# 4   59    blue-collar  married  secondary      no        0     yes   no
# 5   35     management   single   tertiary      no      747      no   no
# 6   36  self-employed  married   tertiary      no      307     yes   no
# 7   39     technician  married  secondary      no      147     yes   no
# 8   41   entrepreneur  married   tertiary      no      221     yes   no
# 9   43       services  married    primary      no      -88     yes  yes
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# ...

# %%
df.describe()
# Out:
#                age       balance          day     duration     campaign  \
# count  4521.000000   4521.000000  4521.000000  4521.000000  4521.000000
# mean     41.170095   1422.657819    15.915284   263.961292     2.793630
# std      10.576211   3009.638142     8.247667   259.856633     3.109807
# min      19.000000  -3313.000000     1.000000     4.000000     1.000000
# 25%      33.000000     69.000000     9.000000   104.000000     1.000000
# 50%      39.000000    444.000000    16.000000   185.000000     2.000000
# 75%      49.000000   1480.000000    21.000000   329.000000     3.000000
# max      87.000000  71188.000000    31.000000  3025.000000    50.000000
#
#              pdays     previous
# count  4521.000000  4521.000000
# mean     39.766645     0.542579
# std     100.121124     1.693562
# min      -1.000000     0.000000
# 25%      -1.000000     0.000000
# 50%      -1.000000     0.000000
# 75%      -1.000000     0.000000
# max     871.000000    25.000000
